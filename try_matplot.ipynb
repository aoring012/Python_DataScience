# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
fig = plt.figure()

# %%
plt.plot(x, np.sin(x), '_')

# %%
plt.plot(x,np.cos(x), '--')

# %%
plt.show()

# %%
p_x = np.random.rand(100)

# %%
p_y = np.random.rand(100)

# %%
plt.scatter(p_x,p_y)

# %%
plt.show()

# %%
data = np.random.randn(10000)

# %%
plt.hist(data)
# Out:
# (array([  31.,  179.,  845., 2053., 2946., 2386., 1201.,  294.,   59.,
#            6.]),
#  array([-3.46650443, -2.71921848, -1.97193253, -1.22464658, -0.47736063,
#          0.26992532,  1.01721127,  1.76449722,  2.51178317,  3.25906913,
#          4.00635508]),
#  <BarContainer object of 10 artists>)

# %%
plt.show()

# %%
x = np.linspace(0,10,100)

# %%
fig = plt.figure()

# %%
plt.plot(x,np.sin(x),'-')

# %%
plt.plot(x,np.cos(x),'--')

# %%
plt.show()

# %%
fig.savefig('test3.png')
